# %%
from IPython.display import IFrame

import songRecommenderProjectUtils2 as proj_utils
## allow output of multiple values per cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

# %%
proj_utils.cluster_feature_heatmap()

# %%
proj_utils.run_recommender()
# Out:
# enter song name: we will rock you
# Enter 0 for 'We Will Rock You - Remastered 2011' by 'Queen'
# Enter 1 for 'We Will Rock You' by 'Five / Queen'
# Enter 2 for 'We Will Rock You - Movie Mix' by 'Queen'
# Enter 3 for 'We Will Rock You - Remastered 2011' by 'Queen'
# Enter 4 for 'We Will Rock You - 2020 Remaster' by 'Nickelback'
# Enter 5 for 'We Will Rock You' by 'Halocene / Violet Orlandi / Lauren Babic / Ai Mori / Caleb Hyles / Jonathan Young / Sershen&Zaritskaya / Cole Rolland / First to Eleven / Lollia'
# Enter 6 for 'We Will Rock You' by 'Nickelback'
# Enter 7 for 'We Will Rock You (feat. Maria Brink, Lzzy Hale and Taylor Momsen)' by 'In This Moment / Lzzy Hale / Maria Brink / Taylor Momsen'
# Enter 8 for 'We Will Rock You' by 'why mona'
# Enter 9 for 'We Will Rock You' by 'Galileo / The Cast Of 'We Will Rock You''
# Enter [SPACE] for 'None of the above'
# 0
# Based on the track:
# 	We Will Rock You - Remastered 2011
# 	by Queen
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4pbJqGIASGPr0ZpGpnWkDn?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# I recommend SIMILAR song:
# (Genre 7
# 	You
# 	by Carpenters
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2OtEBHbCnNUYuRudx8UFs0?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
